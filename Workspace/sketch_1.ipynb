# %%
import cadquery as cq

result = (
    cq.Workplane()
    .sketch()
    .trapezoid(4, 3, 90)
    .vertices()
    .circle(0.5, mode="s")
    .reset()
    .vertices()
    .fillet(0.25)
    .reset()
    .rarray(0.6, 1, 5, 1)
    .slot(1.5, 0.4, mode="s", angle=90)
    .finalize()
    .extrude(1)
)
result

# %%
result = (
    cq.Sketch()
    .trapezoid(4, 3, 90)
    .vertices()
    .circle(0.5, mode="s")
    .reset()
    .vertices()
    .fillet(0.25)
    .reset()
    .rarray(0.6, 1, 5, 1)
    .slot(1.5, 0.4, mode="s", angle=90)
)
result.show_object()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 13
#       1 result = (
#       2     cq.Sketch()
#       3     .trapezoid(4, 3, 90)
#    (...)
#      11     .slot(1.5, 0.4, mode="s", angle=90)
#      12 )
# ---> 13 result.show_object()
#
# AttributeError: 'Sketch' object has no attribute 'show_object'
