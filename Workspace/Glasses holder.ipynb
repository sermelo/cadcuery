# %%
import cadquery as cq

# %%
width = 60
length = 95 # 3 glasses
height = 80
wall = 2
rows = 1
columns = 1

result = (cq.Workplane("front")
    .rect(width, length)
    .extrude(wall)
    .rect(width, length)
    .rect(width-wall, length-wall)
    .extrude(height)
)
result
